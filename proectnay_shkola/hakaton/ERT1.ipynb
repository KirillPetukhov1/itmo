# %%
# import sys

# !{sys.executable} -m pip install -U "transformers>=4.40.0" "datasets" "evaluate" pandas scikit-learn joblib tqdm
# Out:
# Requirement already satisfied: transformers>=4.40.0 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (4.57.1)
# Requirement already satisfied: datasets in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (4.4.0)
# Requirement already satisfied: evaluate in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (0.4.6)
# Requirement already satisfied: pandas in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (2.3.3)
# Requirement already satisfied: scikit-learn in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (1.7.2)
# Requirement already satisfied: joblib in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (1.5.2)
# Requirement already satisfied: tqdm in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (4.67.1)
# Requirement already satisfied: filelock in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from transformers>=4.40.0) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from transformers>=4.40.0) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from transformers>=4.40.0) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from transformers>=4.40.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from transformers>=4.40.0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from transformers>=4.40.0) (2025.10.23)
# Requirement already satisfied: requests in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from transformers>=4.40.0) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from transformers>=4.40.0) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from transformers>=4.40.0) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.40.0) (2025.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.40.0) (4.15.0)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: httpx<1.0.0 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: anyio in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from httpx<1.0.0->datasets) (4.11.0)
# Requirement already satisfied: certifi in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from httpx<1.0.0->datasets) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: colorama in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from requests->transformers>=4.40.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from requests->transformers>=4.40.0) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# WARNING: Ignoring invalid distribution ~orch (C:\Users\botoh\PycharmProjects\BERTA\.venv1\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Users\botoh\PycharmProjects\BERTA\.venv1\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Users\botoh\PycharmProjects\BERTA\.venv1\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# import sys

# # 1. Снести старый torch
# !{sys.executable} -m pip uninstall -y torch torchvision torchaudio

# # 2. Поставить свежий torch с CUDA (12.6)
# !{sys.executable} -m pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126
# Out:
# Found existing installation: torch 2.9.0+cu126
# Uninstalling torch-2.9.0+cu126:
#   Successfully uninstalled torch-2.9.0+cu126
# Found existing installation: torchvision 0.24.0+cu126
# Uninstalling torchvision-0.24.0+cu126:
#   Successfully uninstalled torchvision-0.24.0+cu126
# Found existing installation: torchaudio 2.9.0+cu126
# Uninstalling torchaudio-2.9.0+cu126:
#   Successfully uninstalled torchaudio-2.9.0+cu126
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Collecting torch
#   Using cached https://download.pytorch.org/whl/cu126/torch-2.9.0%2Bcu126-cp311-cp311-win_amd64.whl.metadata (29 kB)
# Collecting torchvision
#   Using cached https://download.pytorch.org/whl/cu126/torchvision-0.24.0%2Bcu126-cp311-cp311-win_amd64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Using cached https://download.pytorch.org/whl/cu126/torchaudio-2.9.0%2Bcu126-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: filelock in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from torch) (2025.9.0)
# Requirement already satisfied: numpy in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from torchvision) (2.3.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\botoh\pycharmprojects\berta\.venv1\lib\site-packages (from jinja2->torch) (3.0.3)
# Using cached https://download.pytorch.org/whl/cu126/torch-2.9.0%2Bcu126-cp311-cp311-win_amd64.whl (2582.7 MB)
# Using cached https://download.pytorch.org/whl/cu126/torchvision-0.24.0%2Bcu126-cp311-cp311-win_amd64.whl (8.5 MB)
# Using cached https://download.pytorch.org/whl/cu126/torchaudio-2.9.0%2Bcu126-cp311-cp311-win_amd64.whl (2.0 MB)
# Installing collected packages: torch, torchvision, torchaudio
#
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    ---------------------------------------- 3/3 [torchaudio]
#
# Successfully installed torch-2.9.0+cu126 torchaudio-2.9.0+cu126 torchvision-0.24.0+cu126
# WARNING: Ignoring invalid distribution ~orch (C:\Users\botoh\PycharmProjects\BERTA\.venv1\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Users\botoh\PycharmProjects\BERTA\.venv1\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Users\botoh\PycharmProjects\BERTA\.venv1\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch

print("Версия torch:", torch.__version__)
print("CUDA доступна?", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Версия torch: 2.6.0+cu118
# CUDA доступна? True
# GPU: NVIDIA GeForce RTX 4060 Ti

# %%
Версия torch: 2.9.0+cu126
CUDA доступна? True
GPU: NVIDIA GeForce RTX 3060 Laptop GPU

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F  # <-- добавили для FocalLoss
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModelForSequenceClassification, get_linear_schedule_with_warmup
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, classification_report
import joblib

# ===== НАСТРОЙКИ =====
# Сейчас ты дообучаешь уже сохранённую модель
MODEL_NAME = "ai-forever/ruBert-base"

CSV_PATH = r"C:\Users\botoh\Downloads\Telegram Desktop\raw_precleaned (2).csv"  # путь к твоему файлу
TEXT_COL = "text"    # колонка с текстом
LABEL_COL = "label"  # колонка с метками

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Используем устройство:", device)

# ===== 1. ЧИТАЕМ ДАННЫЕ =====
df = pd.read_csv(CSV_PATH)
df = df.dropna(subset=[TEXT_COL, LABEL_COL])

print("Всего строк в датасете:", len(df))

# кодируем метки в числа
le = LabelEncoder()
df["label_id"] = le.fit_transform(df[LABEL_COL])

train_df, val_df = train_test_split(
    df,
    test_size=0.2,
    random_state=52,
    stratify=df["label_id"]
)

num_labels = df["label_id"].nunique()
print("Число классов:", num_labels)

# ===== 2. DATASET =====
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

class LettersDataset(Dataset):
    def __init__(self, df, tokenizer, max_length=256):
        self.texts = df[TEXT_COL].astype(str).tolist()
        self.labels = df["label_id"].tolist()
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]

        enc = self.tokenizer(
            text,
            padding="max_length",
            truncation=True,
            max_length=self.max_length,
            return_tensors="pt"
        )

        item = {k: v.squeeze(0) for k, v in enc.items()}
        item["labels"] = torch.tensor(label, dtype=torch.long)
        return item

train_dataset = LettersDataset(train_df, tokenizer, max_length=256)
val_dataset = LettersDataset(val_df, tokenizer, max_length=256)

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

print("Train size:", len(train_dataset), "Val size:", len(val_dataset))

# ===== 3. МОДЕЛЬ, ОПТИМАЙЗЕР, SCHEDULER =====
model = AutoModelForSequenceClassification.from_pretrained(
    MODEL_NAME,
    num_labels=num_labels
).to(device)

# ---- FOCAL LOSS ----
class FocalLoss(nn.Module):
    def __init__(self, gamma=2.0, alpha=None, reduction='mean'):
        """
        gamma > 0 усиливает фокус на сложных примерах.
        alpha можно задать как тензор весов классов (по умолчанию None).
        """
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha
        self.reduction = reduction

    def forward(self, inputs, targets):
        """
        inputs: логиты (batch_size, num_classes)
        targets: индексы классов (batch_size,)
        """
        logpt = F.log_softmax(inputs, dim=-1)   # лог-вероятности
        pt = torch.exp(logpt)                   # вероятности

        # (1 - p)^gamma * log(p)
        focal_logpt = (1 - pt) ** self.gamma * logpt

        loss = F.nll_loss(
            focal_logpt,
            targets,
            weight=self.alpha,
            reduction=self.reduction
        )
        return loss

optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)
criterion = FocalLoss(gamma=2.0)  # <-- используем FocalLoss вместо CrossEntropy

num_epochs = 3
total_steps = len(train_loader) * num_epochs

scheduler = get_linear_schedule_with_warmup(
    optimizer,
    num_warmup_steps=0,
    num_training_steps=total_steps
)

# ===== 4. ФУНКЦИИ ОБУЧЕНИЯ И ВАЛИДАЦИИ =====
def train_one_epoch(model, loader, optimizer, scheduler, criterion, device):
    model.train()
    total_loss = 0.0

    for batch in loader:
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["labels"].to(device)

        optimizer.zero_grad()

        # ВАЖНО: не передаём labels в модель, чтобы она не считала свой CE-loss
        outputs = model(
            input_ids=input_ids,
            attention_mask=attention_mask
        )
        logits = outputs.logits

        # Считаем Focal Loss поверх логитов
        loss = criterion(logits, labels)

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        scheduler.step()

        total_loss += loss.item()

    return total_loss / len(loader)


def evaluate(model, loader, device, le):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for batch in loader:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["labels"].to(device)

            outputs = model(
                input_ids=input_ids,
                attention_mask=attention_mask
            )
            logits = outputs.logits
            preds = torch.argmax(logits, dim=-1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)

    # f1-macro и твой score
    f1_macro = f1_score(all_labels, all_preds, average="macro")

    labels_unique = np.unique(all_labels)
    f1_per_class = f1_score(all_labels, all_preds, average=None, labels=labels_unique)
    variance = np.var(f1_per_class)
    score = f1_macro - 0.1 * np.sqrt(variance)

    # отчёт с текстовыми метками
    true_txt = le.inverse_transform(all_labels)
    pred_txt = le.inverse_transform(all_preds)

    print("\nКлассификационный отчёт (валидация):")
    print(classification_report(true_txt, pred_txt, digits=4))
    print("F1-macro:", f1_macro)
    print("F1 по классам:", dict(zip(le.inverse_transform(labels_unique), f1_per_class)))
    print("Дисперсия F1 по классам:", variance)
    print("Твой score = f1_macro - 0.1 * sqrt(variance) =", score)

    return f1_macro, variance, score

# ===== 5. ЦИКЛ ОБУЧЕНИЯ =====
best_score = -1e9

for epoch in range(1, num_epochs + 1):
    print(f"\n===== Эпоха {epoch}/{num_epochs} =====")
    train_loss = train_one_epoch(model, train_loader, optimizer, scheduler, criterion, device)
    print("Train loss:", train_loss)

    # сначала считаем метрики на валидации
    f1_macro, variance, score = evaluate(model, val_loader, device, le)

    # потом логируем их в файл
    with open("logs.txt", "a", encoding="utf-8") as f:
        f.write(f"\nЭпоха {epoch}\n")
        f.write(f"{f1_macro:.6f} - f1_macro\n{variance:.6f} - дисперсия\n{score:.6f} - score\n")
        f.write("-" * 50 + "\n")

    if score > best_score:
        best_score = score
        print("Новый лучший score! Сохраняем модель...")
        model.save_pretrained("./rubert_letters_best")
        tokenizer.save_pretrained("./rubert_letters_best")
        joblib.dump(le, "./rubert_letters_best/label_encoder.joblib")

print("\nОбучение завершено. Лучший score:", best_score)
# Out:
# Используем устройство: cuda
# Всего строк в датасете: 1380
# Число классов: 36
# Train size: 1104 Val size: 276
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at ai-forever/ruBert-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ===== Эпоха 1/3 =====
# Train loss: 2.835017497124879
#
# Классификационный отчёт (валидация):
#                                                                               precision    recall  f1-score   support
#
#                                                        Блок бизнес-директора     0.0000    0.0000    0.0000         1
#                                                       Блок деректора по газу     0.0000    0.0000    0.0000        11
#                                           Блок директора по газовым проектам     0.0000    0.0000    0.0000         5
#                                                  Блок директора по мощностям     0.0000    0.0000    0.0000        38
#                                                  Блок директора по персоналу     0.0000    0.0000    0.0000         3
#                                                   Блок директора по портфелю     0.0000    0.0000    0.0000         4
#                                             Блок директора по проектированию     0.0000    0.0000    0.0000         7
#                                              Блок директора по строительству     0.0000    0.0000    0.0000        25
#                      Блок заместителя генерального директора по безопасности     0.0000    0.0000    0.0000        20
#                          Блок заместителя генерального директора по закупкам     0.0000    0.0000    0.0000        11
#                            Блок заместителя генерального директора по защите     0.0000    0.0000    0.0000         4
#                         Блок заместителя генерального директора по имуществу     0.0000    0.0000    0.0000         3
#          Блок заместителя генерального директора по организационным вопросам     0.0000    0.0000    0.0000         9
# Блок исполнительного директора по реализации проекта "Большое месторождение"     0.0000    0.0000    0.0000         1
#                                                 Блок операционного директора     0.0000    0.0000    0.0000         5
#                                                  Блок технического директора     0.1450    1.0000    0.2532        39
#                                                   Блок финансового директора     0.0000    0.0000    0.0000         4
#                                                         Генеральный директор     0.0000    0.0000    0.0000        16
#                                                           Проект "Восточный"     0.0000    0.0000    0.0000         3
#                                                    Проект "Нефтяные краюшки"     0.0000    0.0000    0.0000        12
#                                                         Проект "Новая нефть"     0.0000    0.0000    0.0000         6
#                       Проект "Обустройство площадных объектов НГКМ Поменбше"     0.0000    0.0000    0.0000         1
#                                                    Проект "Северная деревня"     0.0000    0.0000    0.0000         6
#                              Проект "Трубопроводный транспорт Главного НГКМ"     0.0000    0.0000    0.0000         3
#                                                               Проект "Южный"     0.0000    0.0000    0.0000         2
#                      Проект «Обустройство Интересного лицензионного участка»     0.0000    0.0000    0.0000         1
#                                   Проект «Обустройство объектов Новой нефти»     0.0000    0.0000    0.0000         3
#                                                       Проект сервиса скважин     0.0000    0.0000    0.0000         7
#                                          Управление землеустроительных работ     0.0000    0.0000    0.0000         4
#                                                      Управление коммуникаций     0.0000    0.0000    0.0000         1
#                                              Управление по проектным работам     0.0000    0.0000    0.0000        21
#
#                                                                     accuracy                         0.1413       276
#                                                                    macro avg     0.0047    0.0323    0.0082       276
#                                                                 weighted avg     0.0205    0.1413    0.0358       276
#
# F1-macro: 0.008169250104733974
# F1 по классам: {'Блок бизнес-директора': np.float64(0.0), 'Блок деректора по газу': np.float64(0.0), 'Блок директора по газовым проектам': np.float64(0.0), 'Блок директора по мощностям': np.float64(0.0), 'Блок директора по персоналу': np.float64(0.0), 'Блок директора по портфелю': np.float64(0.0), 'Блок директора по проектированию': np.float64(0.0), 'Блок директора по строительству': np.float64(0.0), 'Блок заместителя генерального директора по безопасности': np.float64(0.0), 'Блок заместителя генерального директора по закупкам': np.float64(0.0), 'Блок заместителя генерального директора по защите': np.float64(0.0), 'Блок заместителя генерального директора по имуществу': np.float64(0.0), 'Блок заместителя генерального директора по организационным вопросам': np.float64(0.0), 'Блок исполнительного директора по реализации проекта "Большое месторождение"': np.float64(0.0), 'Блок операционного директора': np.float64(0.0), 'Блок технического директора': np.float64(0.2532467532467532), 'Блок финансового директора': np.float64(0.0), 'Генеральный директор': np.float64(0.0), 'Проект "Восточный"': np.float64(0.0), 'Проект "Нефтяные краюшки"': np.float64(0.0), 'Проект "Новая нефть"': np.float64(0.0), 'Проект "Обустройство площадных объектов НГКМ Поменбше"': np.float64(0.0), 'Проект "Северная деревня"': np.float64(0.0), 'Проект "Трубопроводный транспорт Главного НГКМ"': np.float64(0.0), 'Проект "Южный"': np.float64(0.0), 'Проект «Обустройство Интересного лицензионного участка»': np.float64(0.0), 'Проект «Обустройство объектов Новой нефти»': np.float64(0.0), 'Проект сервиса скважин': np.float64(0.0), 'Управление землеустроительных работ': np.float64(0.0), 'Управление коммуникаций': np.float64(0.0), 'Управление по проектным работам': np.float64(0.0)}
# Дисперсия F1 по классам: 0.0020020994182108824
# Твой score = f1_macro - 0.1 * sqrt(variance) = 0.0036947675444697348
# Новый лучший score! Сохраняем модель...
# C:\Users\botoh\PycharmProjects\BERTA\.venv1\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\botoh\PycharmProjects\BERTA\.venv1\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\botoh\PycharmProjects\BERTA\.venv1\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ===== Эпоха 2/3 =====
# Train loss: 2.470520105914793
#
# Классификационный отчёт (валидация):
#                                                                               precision    recall  f1-score   support
#
#                                                        Блок бизнес-директора     0.0000    0.0000    0.0000         1
#                                                       Блок деректора по газу     0.0000    0.0000    0.0000        11
#                                           Блок директора по газовым проектам     0.0000    0.0000    0.0000         5
#                                                  Блок директора по мощностям     0.3750    0.8684    0.5238        38
#                                                  Блок директора по персоналу     0.0000    0.0000    0.0000         3
#                                                   Блок директора по портфелю     0.0000    0.0000    0.0000         4
#                                             Блок директора по проектированию     0.0000    0.0000    0.0000         7
#                                              Блок директора по строительству     0.6250    0.6000    0.6122        25
#                      Блок заместителя генерального директора по безопасности     0.4348    0.5000    0.4651        20
#                          Блок заместителя генерального директора по закупкам     0.0000    0.0000    0.0000        11
#                            Блок заместителя генерального директора по защите     0.0000    0.0000    0.0000         4
#                         Блок заместителя генерального директора по имуществу     0.0000    0.0000    0.0000         3
#          Блок заместителя генерального директора по организационным вопросам     0.0000    0.0000    0.0000         9
# Блок исполнительного директора по реализации проекта "Большое месторождение"     0.0000    0.0000    0.0000         1
#                                                 Блок операционного директора     0.0000    0.0000    0.0000         5
#                                                  Блок технического директора     0.2621    0.6923    0.3803        39
#                                                   Блок финансового директора     0.0000    0.0000    0.0000         4
#                                                         Генеральный директор     0.7500    0.3750    0.5000        16
#                                                           Проект "Восточный"     0.0000    0.0000    0.0000         3
#                                                    Проект "Нефтяные краюшки"     0.0000    0.0000    0.0000        12
#                                                         Проект "Новая нефть"     0.0000    0.0000    0.0000         6
#                       Проект "Обустройство площадных объектов НГКМ Поменбше"     0.0000    0.0000    0.0000         1
#                                                    Проект "Северная деревня"     0.0000    0.0000    0.0000         6
#                              Проект "Трубопроводный транспорт Главного НГКМ"     0.0000    0.0000    0.0000         3
#                                                               Проект "Южный"     0.0000    0.0000    0.0000         2
#                      Проект «Обустройство Интересного лицензионного участка»     0.0000    0.0000    0.0000         1
#                                   Проект «Обустройство объектов Новой нефти»     0.0000    0.0000    0.0000         3
#                                                       Проект сервиса скважин     0.0000    0.0000    0.0000         7
#                                          Управление землеустроительных работ     0.0000    0.0000    0.0000         4
#                                                      Управление коммуникаций     0.0000    0.0000    0.0000         1
#                                              Управление по проектным работам     0.5667    0.8095    0.6667        21
#
#                                                                     accuracy                         0.3913       276
#                                                                    macro avg     0.0972    0.1240    0.1016       276
#                                                                 weighted avg     0.2634    0.3913    0.2947       276
#
# F1-macro: 0.10155222766599957
# F1 по классам: {'Блок бизнес-директора': np.float64(0.0), 'Блок деректора по газу': np.float64(0.0), 'Блок директора по газовым проектам': np.float64(0.0), 'Блок директора по мощностям': np.float64(0.5238095238095238), 'Блок директора по персоналу': np.float64(0.0), 'Блок директора по портфелю': np.float64(0.0), 'Блок директора по проектированию': np.float64(0.0), 'Блок директора по строительству': np.float64(0.6122448979591837), 'Блок заместителя генерального директора по безопасности': np.float64(0.46511627906976744), 'Блок заместителя генерального директора по закупкам': np.float64(0.0), 'Блок заместителя генерального директора по защите': np.float64(0.0), 'Блок заместителя генерального директора по имуществу': np.float64(0.0), 'Блок заместителя генерального директора по организационным вопросам': np.float64(0.0), 'Блок исполнительного директора по реализации проекта "Большое месторождение"': np.float64(0.0), 'Блок операционного директора': np.float64(0.0), 'Блок технического директора': np.float64(0.38028169014084506), 'Блок финансового директора': np.float64(0.0), 'Генеральный директор': np.float64(0.5), 'Проект "Восточный"': np.float64(0.0), 'Проект "Нефтяные краюшки"': np.float64(0.0), 'Проект "Новая нефть"': np.float64(0.0), 'Проект "Обустройство площадных объектов НГКМ Поменбше"': np.float64(0.0), 'Проект "Северная деревня"': np.float64(0.0), 'Проект "Трубопроводный транспорт Главного НГКМ"': np.float64(0.0), 'Проект "Южный"': np.float64(0.0), 'Проект «Обустройство Интересного лицензионного участка»': np.float64(0.0), 'Проект «Обустройство объектов Новой нефти»': np.float64(0.0), 'Проект сервиса скважин': np.float64(0.0), 'Управление землеустроительных работ': np.float64(0.0), 'Управление коммуникаций': np.float64(0.0), 'Управление по проектным работам': np.float64(0.6666666666666666)}
# Дисперсия F1 по классам: 0.04467462872275492
# Твой score = f1_macro - 0.1 * sqrt(variance) = 0.08041585410695332
# Новый лучший score! Сохраняем модель...
# C:\Users\botoh\PycharmProjects\BERTA\.venv1\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\botoh\PycharmProjects\BERTA\.venv1\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\botoh\PycharmProjects\BERTA\.venv1\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ===== Эпоха 3/3 =====
# Train loss: 2.0451303392216778
#
# Классификационный отчёт (валидация):
#                                                                               precision    recall  f1-score   support
#
#                                                        Блок бизнес-директора     0.0000    0.0000    0.0000         1
#                                                       Блок деректора по газу     0.0000    0.0000    0.0000        11
#                                           Блок директора по газовым проектам     0.0000    0.0000    0.0000         5
#                                                  Блок директора по мощностям     0.4762    0.7895    0.5941        38
#                                                  Блок директора по персоналу     0.0000    0.0000    0.0000         3
#                                                   Блок директора по портфелю     0.0000    0.0000    0.0000         4
#                                             Блок директора по проектированию     0.0000    0.0000    0.0000         7
#                                              Блок директора по строительству     0.5312    0.6800    0.5965        25
#                      Блок заместителя генерального директора по безопасности     0.4348    0.5000    0.4651        20
#                          Блок заместителя генерального директора по закупкам     0.0000    0.0000    0.0000        11
#                            Блок заместителя генерального директора по защите     0.0000    0.0000    0.0000         4
#                         Блок заместителя генерального директора по имуществу     0.0000    0.0000    0.0000         3
#          Блок заместителя генерального директора по организационным вопросам     0.0000    0.0000    0.0000         9
# Блок исполнительного директора по реализации проекта "Большое месторождение"     0.0000    0.0000    0.0000         1
#                                                 Блок операционного директора     0.0000    0.0000    0.0000         5
#                                                  Блок технического директора     0.2982    0.8718    0.4444        39
#                                                   Блок финансового директора     0.0000    0.0000    0.0000         4
#                                                         Генеральный директор     0.6667    0.3750    0.4800        16
#                                                           Проект "Восточный"     0.0000    0.0000    0.0000         3
#                                                    Проект "Нефтяные краюшки"     0.0000    0.0000    0.0000        12
#                                                         Проект "Новая нефть"     0.0000    0.0000    0.0000         6
#                       Проект "Обустройство площадных объектов НГКМ Поменбше"     0.0000    0.0000    0.0000         1
#                                                    Проект "Северная деревня"     0.0000    0.0000    0.0000         6
#                              Проект "Трубопроводный транспорт Главного НГКМ"     0.0000    0.0000    0.0000         3
#                                                               Проект "Южный"     0.0000    0.0000    0.0000         2
#                      Проект «Обустройство Интересного лицензионного участка»     0.0000    0.0000    0.0000         1
#                                   Проект «Обустройство объектов Новой нефти»     0.0000    0.0000    0.0000         3
#                                                       Проект сервиса скважин     0.0000    0.0000    0.0000         7
#                                          Управление землеустроительных работ     0.0000    0.0000    0.0000         4
#                                                      Управление коммуникаций     0.0000    0.0000    0.0000         1
#                                              Управление по проектным работам     0.5429    0.9048    0.6786        21
#
#                                                                     accuracy                         0.4203       276
#                                                                    macro avg     0.0952    0.1329    0.1051       276
#                                                                 weighted avg     0.2673    0.4203    0.3118       276
#
# F1-macro: 0.10511879955149708
# F1 по классам: {'Блок бизнес-директора': np.float64(0.0), 'Блок деректора по газу': np.float64(0.0), 'Блок директора по газовым проектам': np.float64(0.0), 'Блок директора по мощностям': np.float64(0.594059405940594), 'Блок директора по персоналу': np.float64(0.0), 'Блок директора по портфелю': np.float64(0.0), 'Блок директора по проектированию': np.float64(0.0), 'Блок директора по строительству': np.float64(0.5964912280701754), 'Блок заместителя генерального директора по безопасности': np.float64(0.46511627906976744), 'Блок заместителя генерального директора по закупкам': np.float64(0.0), 'Блок заместителя генерального директора по защите': np.float64(0.0), 'Блок заместителя генерального директора по имуществу': np.float64(0.0), 'Блок заместителя генерального директора по организационным вопросам': np.float64(0.0), 'Блок исполнительного директора по реализации проекта "Большое месторождение"': np.float64(0.0), 'Блок операционного директора': np.float64(0.0), 'Блок технического директора': np.float64(0.4444444444444444), 'Блок финансового директора': np.float64(0.0), 'Генеральный директор': np.float64(0.48), 'Проект "Восточный"': np.float64(0.0), 'Проект "Нефтяные краюшки"': np.float64(0.0), 'Проект "Новая нефть"': np.float64(0.0), 'Проект "Обустройство площадных объектов НГКМ Поменбше"': np.float64(0.0), 'Проект "Северная деревня"': np.float64(0.0), 'Проект "Трубопроводный транспорт Главного НГКМ"': np.float64(0.0), 'Проект "Южный"': np.float64(0.0), 'Проект «Обустройство Интересного лицензионного участка»': np.float64(0.0), 'Проект «Обустройство объектов Новой нефти»': np.float64(0.0), 'Проект сервиса скважин': np.float64(0.0), 'Управление землеустроительных работ': np.float64(0.0), 'Управление коммуникаций': np.float64(0.0), 'Управление по проектным работам': np.float64(0.6785714285714286)}
# Дисперсия F1 по классам: 0.047447830364009055
# Твой score = f1_macro - 0.1 * sqrt(variance) = 0.08333627665721116
# Новый лучший score! Сохраняем модель...
# C:\Users\botoh\PycharmProjects\BERTA\.venv1\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\botoh\PycharmProjects\BERTA\.venv1\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\botoh\PycharmProjects\BERTA\.venv1\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Обучение завершено. Лучший score: 0.08333627665721116
