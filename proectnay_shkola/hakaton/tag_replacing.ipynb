# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from deep_translator import GoogleTranslator
import time

# %%
df = pd.read_json('train_hackathon_dataset.json') # изменить путь
df
# Out:
#                                                     idx  \
# 0                                                 10026
# 1                                                  1005
# 2                                                  1010
# 3                                                  1013
# 4                                                 10186
# ...                                                 ...
# 1619  new_Проект «Обустройство объектов Новейшей ней...
# 1620  new_Проект «Обустройство объектов Новейшей ней...
# 1621  new_Проект «Обустройство объектов Новейшей ней...
# 1622  new_Проект «Обустройство объектов Новейшей ней...
# 1623  new_Проект «Обустройство объектов Новейшей ней...
#
#                                                    text  \
# 0     [PERSON]\r\n\r\nУважаемый [PERSON]!\r\n\r\n[OR...
# 1     [ORGANIZATION] инжиниринг общество с ограничен...
# 2     [ORGANIZATION] ИНВЕСТ Общество с ограниченной ...
# 3     [ORGANIZATION] филиал [OBJECT] имени [PERSON] ...
# ...

# %%
raw_tags = ['[PROJECT]', '[TYPE]', '[SIZE]', '[НОМЕР_ОБЪЕКТА]', '[REGIONAL_OFFICE]', '[NUMBER]', '[MUNICIPAL_DISTRICT]', '[OGRN]', '[CITY]', '[TIME]', '[DIMENSIONS]', '[NUMBER_OF_PAGES]', '[PRODUCT]', '[SIGNATURE]', '[SERVICE_AREA]', '[LAW_NUMBER]', '[QUANTITY]', '[PAGE]', '[PRODUCT_MARK]', '[PROJECT_NUMBER]', '[EXECUTIVE_DIRECTOR]', '[TEMPERATURE]', '[DOMAIN]', '[FILIAL]', '[DATE]', '[KPP]', '[VOLUME]', '[RESOURCE_TYPES]', '[SKVAGH_NUMBER]', '[DIAGNOSIS]', '[PAGE_NUMBER]', '[FRACTION]', '[WORK_TYPE]', '[ELECTRONIC_SIGNATURE]', '[DOCUMENT_SIGNATURE]', '[NETWORK]', '[NAME_OF_FIELD]', '[DISTANCE]', '[AUTONOMOUS_REGION]', '[URL]', '[DISTRICT]', '[DIRECTOR]', '[PLACE]', '[PLAN]', '[CHEMICAL_REAGENT]', '[WWW]', '[TITLE]', '[PROJECT_NAME]', '[PHONE_PROVIDER]', '[SYSTEM]', '[REGION]', '[ID]', '[LICENSE]', '[CURRENCY]', '[BIC]', '[PIPELINE]', '[AREA]', '[RIVER]', '[DEPOSITS]', '[ЛОКАЦИЯ]', '[ACTIVITY]', '[LENGTH]', '[DELIVERY_DATE]', '[BANK_ID]', '[YEAR]', '[JOB_TITLE]', '[TYPE_OF_ORDER]', '[WORK]', '[CERTIFICATE]', '[DEVICE]', '[STANDARD]', '[REPUBLIC]', '[SPEED]', '[НОМЕР_ДОКУМЕНТА]', '[ADDRESS]', '[ROOM]', '[PERIOD]', '[MODEL]', '[TDU]', '[MINISTRY]', '[BUILDING_NUMBER]', '[KPZ]', '[ORGANIZATION]', '[EVENT]', '[ORGANIZATION_ID]', '[STAGE]', '[POSITION]', '[COPY_COUNT]', '[PROCESSING_STANDARD]', '[EMAIL]', '[SNAB]', '[АДРЕС_ЭЛ_ПОЧТЫ]', '[DIVISION]', '[ACTION]', '[MARK]', '[INSTRUMENT_TYPE]', '[POSTAL_CODE]', '[STAND]', '[VALUE]', '[COPIES]', '[POSTCODE]', '[BANK]', '[STORAGE_PRICE]', '[OFFICE]', '[LETTER]', '[DEPARTMENT]', '[AMOUNT]', '[LAYER]', '[WIND_DIRECTION]', '[REGIONAL_AREA]', '[SPECIFICATION]', '[CATEGORY]', '[CONFERENCING]', '[PROJECT_CODE]', '[REGULATORY_INTERACTION]', '[WAREHOUSE_LIMIT]', '[OPERATOR]', '[PRICE_PER_UNIT]', '[TOPIC]', '[CODE]', '[UNIT]', '[WEBSITE]', '[OPERATION]', '[ДАТА]', '[SECTION]', '[TABLE_NUMBER]', '[COUNTRY]', '[VH_NO]', '[LOCATION]', '[CONNECTION_TYPE]', '[FINANCИAL_DATA]', '[DIMENSION]', '[SOFTWARE]', '[NOTES]', '[INTERNAL_REGULATION]', '[P]', '[ENGINE_MODEL]', '[PROTOCOL]', '[LICENSED_AREA]', '[INDIVIDUAL_PREMISE]', '[ИМЯ_ЧЕЛОВЕКА]', '[FUNCTION]', '[PROSPECT]', '[SCHEME]', '[GAS_PIPELINE]', '[STANDARD_NUMBER]', '[LAND_TYPE]', '[INN]', '[SERVICE_CODE]', '[DO]', '[COPY]', '[VEHICLE]', '[INN_KPP]', '[SUBORGANIZATION]', '[CONDITIONS]', '[REPRESENTATIVE]', '[NPS_AREA]', '[DOCUMENT_NUMBER]', '[PROFESSION]', '[BRANCH]', '[HOUSE]', '[CONFERENCING_LINK]', '[CENTRE]', '[BRAND]', '[ОБЛАСТЬ]', '[НОМЕР_ТЕЛЕФОНА]', '[NAME]', '[NOMINATION_2]', '[REGULATORY_DOCUMENT]', '[GEN_DIR]', '[ORGANIZATION_NUMBER]', '[PERSON]', '[ADMINISTRATION]', '[OBJECT]', '[GROUP]', '[OKPO]', '[THICKNESS]', '[ROUTE]', '[PAGE_COUNT]', '[PRODUCT_CODE]', '[PAGES]', '[DOCUMENT]', '[CONDITION]', '[VEHICLE_TYPE]', '[FIELD]', '[PHONE]', '[ETHNIC_GROUP]', '[MANAGER]', '[RECONSTRUCTION]', '[FINANCIAL_DIRECTOR]', '[НАЗВАНИЕ_КОМПАНИИ]', '[COMPETITION_NAME]', '[SERVICES]', '[MEASURES]', '[DESCRIPTION]', '[RESOLUTION]', '[DEPTH]', '[HALL]', '[FINANCИАL_DATA]', '[GOVERNMENT]', '[CENTRAL_BANK_OF_RUSSIA]', '[COPY_TO]', '[COMPRESSOR_MODEL]', '[ISLAND]', '[DIRECTION]', '[PRODUCT_TYPE]', '[MONTH]', '[GENERAL_DIRECTOR]', '[STATION]', '[POST_CODE]', '[WEB]', '[WORKPLACE]', '[OFFICE_NUMBER]', '[MAX_QUANTITY_ON_WAREHOUSE]', '[FINANCИАЛЬ_ДАННЫЕ]', '[QUARTER]', '[FINANCИАЛЬ_DATA]', '[FINANCIAL_DATA]', '[DATE_RANGE]', '[YEAR+1]', '[DATE_TIME]', '[DOCUMENT_TYPE]', '[FILE_EXTENSION]', '[ZIP_CODE]', '[CONTACT]', '[ВРЕМЯ]', '[FILE_SIZE]', '[MUNICIPAL_AREA]', '[INSTITUTION]', '[TAX_ID]', '[TOTAL_PRICE]']

# %%
len(raw_tags)
# Out:
# 231

# %%
tags_dict = {}
    
for tag in raw_tags:
    try:
        tags_dict[tag] = '[' + GoogleTranslator(source='en', target='ru').translate(tag[1:-1].replace('_', ' ')).upper().replace(' ', '_') + ']'
        time.sleep(0.1)
    except Exception as e:
        print(tag, e)
        tags_dict[tag] = tag
    
for i in tags_dict:
    print(f'{i}: {tags_dict[i]}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 5
#       3 for tag in raw_tags:
#       4     try:
# ----> 5         tags_dict[tag] = '[' + GoogleTranslator(source='en', target='ru').translate(tag[1:-1].replace('_', ' ')).upper().replace(' ', '_') + ']'
#       6         time.sleep(0.1)
#       7     except Exception as e:
#
# File c:\Users\k4484\anaconda3\envs\proectnayShkola\Lib\site-packages\deep_translator\google.py:67, in GoogleTranslator.translate(self, text, **kwargs)
#      64 if self.payload_key:
#      65     self._url_params[self.payload_key] = text
# ---> 67 response = requests.get(
#      68     self._base_url, params=self._url_params, proxies=self.proxies
#      69 )
#      70 if response.status_code == 429:
#      71     raise TooManyRequests()
#
# ...

# %%
GoogleTranslator(source='en', target='ru').translate('TIME')
# Out:
# 'ВРЕМЯ'

# %%
tags_dict = {'[PROJECT]': '[ПРОЕКТ]',
 '[TYPE]': '[ТИП]',
 '[SIZE]': '[РАЗМЕР]',
 '[НОМЕР_ОБЪЕКТА]': '[НОМЕР_ОБЪЕКТА]',
 '[REGIONAL_OFFICE]': '[РЕГИОНАЛЬНЫЙ_ОФИС]',
 '[NUMBER]': '[ЧИСЛО]',
 '[MUNICIPAL_DISTRICT]': '[МУНИЦИПАЛЬНЫЙ_ОКРУГ]',
 '[OGRN]': '[ОГРН]',
 '[CITY]': '[ГОРОД]',
 '[TIME]': '[ВРЕМЯ]',
 '[DIMENSIONS]': '[РАЗМЕРЫ]',
 '[NUMBER_OF_PAGES]': '[КОЛИЧЕСТВО_СТРАНИЦ]',
 '[PRODUCT]': '[ПРОДУКТ]',
 '[SIGNATURE]': '[ПОДПИСЬ]',
 '[SERVICE_AREA]': '[ЗОНА_ОБСЛУЖИВАНИЯ]',
 '[LAW_NUMBER]': '[НОМЕР_ЗАКОНА]',
 '[QUANTITY]': '[КОЛИЧЕСТВО]',
 '[PAGE]': '[СТРАНИЦА]',
 '[PRODUCT_MARK]': '[МАРКА_ПРОДУКТА]',
 '[PROJECT_NUMBER]': '[НОМЕР_ПРОЕКТА]',
 '[EXECUTIVE_DIRECTOR]': '[ИСПОЛНИТЕЛЬНЫЙ_ДИРЕКТОР]',
 '[TEMPERATURE]': '[ТЕМПЕРАТУРА]',
 '[DOMAIN]': '[ДОМЕН]',
 '[FILIAL]': '[ФИЛИАЛ]',
 '[DATE]': '[ДАТА]',
 '[KPP]': '[КПП]',
 '[VOLUME]': '[ОБЪЕМ]',
 '[RESOURCE_TYPES]': '[ТИПЫ_РЕСУРСОВ]',
 '[SKVAGH_NUMBER]': '[НОМЕР_СКВАХА]',
 '[DIAGNOSIS]': '[ДИАГНОСТИКА]',
 '[PAGE_NUMBER]': '[НОМЕР_СТРАНИЦЫ]',
 '[FRACTION]': '[ФРАКЦИЯ]',
 '[WORK_TYPE]': '[ТИП_РАБОТЫ]',
 '[ELECTRONIC_SIGNATURE]': '[ЭЛЕКТРОННАЯ_ПОДПИСЬ]',
 '[DOCUMENT_SIGNATURE]': '[ПОДПИСЬ_ДОКУМЕНТА]',
 '[NETWORK]': '[СЕТЬ]',
 '[NAME_OF_FIELD]': '[НАЗВАНИЕ_ПОЛЯ]',
 '[DISTANCE]': '[РАССТОЯНИЕ]',
 '[AUTONOMOUS_REGION]': '[АВТОНОМНАЯ_ОБЛАСТЬ]',
 '[URL]': '[URL-АДРЕС]',
 '[DISTRICT]': '[ОКРУГ]',
 '[DIRECTOR]': '[ДИРЕКТОР]',
 '[PLACE]': '[МЕСТО]',
 '[PLAN]': '[ПЛАН]',
 '[CHEMICAL_REAGENT]': '[ХИМИЧЕСКИЙ_РЕАГЕНТ]',
 '[WWW]': '[WWW]',
 '[TITLE]': '[ЗАГОЛОВОК]',
 '[PROJECT_NAME]': '[НАЗВАНИЕ_ПРОЕКТА]',
 '[PHONE_PROVIDER]': '[ТЕЛЕФОННЫЙ_ПРОВАЙДЕР]',
 '[SYSTEM]': '[СИСТЕМА]',
 '[REGION]': '[ОБЛАСТЬ]',
 '[ID]': '[ИДЕНТИФИКАТОР]',
 '[LICENSE]': '[ЛИЦЕНЗИЯ]',
 '[CURRENCY]': '[ВАЛЮТА]',
 '[BIC]': '[БИК]',
 '[PIPELINE]': '[ТРУБОПРОВОД]',
 '[AREA]': '[ОБЛАСТЬ]',
 '[RIVER]': '[РЕКА]',
 '[DEPOSITS]': '[ДЕПОЗИТЫ]',
 '[ЛОКАЦИЯ]': '[ЛОКАЦИЯ]',
 '[ACTIVITY]': '[АКТИВНОСТЬ]',
 '[LENGTH]': '[ДЛИНА]',
 '[DELIVERY_DATE]': '[ДАТА_ДОСТАВКИ]',
 '[BANK_ID]': '[ИДЕНТИФИКАТОР_БАНКА]',
 '[YEAR]': '[ГОД]',
 '[JOB_TITLE]': '[ДОЛЖНОСТЬ]',
 '[TYPE_OF_ORDER]': '[ТИП_ЗАКАЗА]',
 '[WORK]': '[РАБОТА]',
 '[CERTIFICATE]': '[СЕРТИФИКАТ]',
 '[DEVICE]': '[УСТРОЙСТВО]',
 '[STANDARD]': '[СТАНДАРТ]',
 '[REPUBLIC]': '[РЕСПУБЛИКА]',
 '[SPEED]': '[СКОРОСТЬ]',
 '[НОМЕР_ДОКУМЕНТА]': '[НОМЕР_ДОКУМЕНТА]',
 '[ADDRESS]': '[АДРЕС]',
 '[ROOM]': '[КОМНАТА]',
 '[PERIOD]': '[ПЕРИОД]',
 '[MODEL]': '[МОДЕЛЬ]',
 '[TDU]': '[ТДУ]',
 '[MINISTRY]': '[МИНИСТЕРСТВО]',
 '[BUILDING_NUMBER]': '[НОМЕР_ЗДАНИЯ]',
 '[KPZ]': '[КПЗ]',
 '[ORGANIZATION]': '[ОРГАНИЗАЦИЯ]',
 '[EVENT]': '[СОБЫТИЕ]',
 '[ORGANIZATION_ID]': '[ИДЕНТИФИКАТОР_ОРГАНИЗАЦИИ]',
 '[STAGE]': '[ЭТАП]',
 '[POSITION]': '[ПОЗИЦИЯ]',
 '[COPY_COUNT]': '[СЧЕТ_КОПИЙ]',
 '[PROCESSING_STANDARD]': '[СТАНДАРТ_ОБРАБОТКИ]',
 '[EMAIL]': '[ЭЛЕКТРОННАЯ_ПОЧТА]',
 '[SNAB]': '[СНАБ]',
 '[АДРЕС_ЭЛ_ПОЧТЫ]': '[АДРЕС_ЭЛ_ПОЧТЫ]',
 '[DIVISION]': '[РАЗДЕЛЕНИЕ]',
 '[ACTION]': '[ДЕЙСТВИЕ]',
 '[MARK]': '[ОТМЕТКА]',
 '[INSTRUMENT_TYPE]': '[ТИП_ПРИБОРА]',
 '[POSTAL_CODE]': '[ПОЧТОВЫЙ_ИНДЕКС]',
 '[STAND]': '[СТОЯТЬ]',
 '[VALUE]': '[ЦЕНИТЬ]',
 '[COPIES]': '[КОПИИ]',
 '[POSTCODE]': '[ПОЧТОВЫЙ_ИНДЕКС]',
 '[BANK]': '[БАНК]',
 '[STORAGE_PRICE]': '[ЦЕНА_ХРАНЕНИЯ]',
 '[OFFICE]': '[ОФИС]',
 '[LETTER]': '[ПИСЬМО]',
 '[DEPARTMENT]': '[ОТДЕЛЕНИЕ]',
 '[AMOUNT]': '[КОЛИЧЕСТВО]',
 '[LAYER]': '[СЛОЙ]',
 '[WIND_DIRECTION]': '[НАПРАВЛЕНИЕ_ВЕТРА]',
 '[REGIONAL_AREA]': '[РЕГИОНАЛЬНАЯ_ОБЛАСТЬ]',
 '[SPECIFICATION]': '[СПЕЦИФИКАЦИЯ]',
 '[CATEGORY]': '[КАТЕГОРИЯ]',
 '[CONFERENCING]': '[КОНФЕРЕНЦИИ]',
 '[PROJECT_CODE]': '[КОД_ПРОЕКТА]',
 '[REGULATORY_INTERACTION]': '[НОРМАТИВНОЕ_ВЗАИМОДЕЙСТВИЕ]',
 '[WAREHOUSE_LIMIT]': '[СКЛАДСКИЙ_ЛИМИТ]',
 '[OPERATOR]': '[ОПЕРАТОР]',
 '[PRICE_PER_UNIT]': '[ЦЕНА_ЗА_ЕДИНИЦУ]',
 '[TOPIC]': '[ТЕМА]',
 '[CODE]': '[КОД]',
 '[UNIT]': '[ЕДИНИЦА]',
 '[WEBSITE]': '[ВЕБ-САЙТ]',
 '[OPERATION]': '[ЭКСПЛУАТАЦИЯ]',
 '[ДАТА]': '[ДАННЫЕ]',
 '[SECTION]': '[РАЗДЕЛ]',
 '[TABLE_NUMBER]': '[НОМЕР_ТАБЛИЦЫ]',
 '[COUNTRY]': '[СТРАНА]',
 '[VH_NO]': '[ВХ_НЕТ]',
 '[LOCATION]': '[РАСПОЛОЖЕНИЕ]',
 '[CONNECTION_TYPE]': '[ТИП_СОЕДИНЕНИЯ]',
 '[FINANCИAL_DATA]': '[ФИНАНСОВЫЕ_ДАННЫЕ]',
 '[DIMENSION]': '[ИЗМЕРЕНИЕ]',
 '[SOFTWARE]': '[ПРОГРАММНОЕ_ОБЕСПЕЧЕНИЕ]',
 '[NOTES]': '[ПРИМЕЧАНИЯ]',
 '[INTERNAL_REGULATION]': '[ВНУТРЕННЕЕ_ПРАВИЛО]',
 '[P]': '[П]',
 '[ENGINE_MODEL]': '[МОДЕЛЬ_ДВИГАТЕЛЯ]',
 '[PROTOCOL]': '[ПРОТОКОЛ]',
 '[LICENSED_AREA]': '[ЛИЦЕНЗИРОВАННАЯ_ЗОНА]',
 '[INDIVIDUAL_PREMISE]': '[ИНДИВИДУАЛЬНОЕ_ПОМЕЩЕНИЕ]',
 '[ИМЯ_ЧЕЛОВЕКА]': '[ИМЯ_ЧЕЛОВЕКА]',
 '[FUNCTION]': '[ФУНКЦИЯ]',
 '[PROSPECT]': '[ПЕРСПЕКТИВА]',
 '[SCHEME]': '[СХЕМА]',
 '[GAS_PIPELINE]': '[ГАЗОПРОВОД]',
 '[STANDARD_NUMBER]': '[СТАНДАРТНЫЙ_НОМЕР]',
 '[LAND_TYPE]': '[ТИП_ЗЕМЛИ]',
 '[INN]': '[ГОСТИНИЦА]',
 '[SERVICE_CODE]': '[СЕРВИСНЫЙ_КОД]',
 '[DO]': '[СДЕЛАТЬ]',
 '[COPY]': '[КОПИРОВАТЬ]',
 '[VEHICLE]': '[ТРАНСПОРТНОЕ_СРЕДСТВО]',
 '[INN_KPP]': '[ИНН_КПП]',
 '[SUBORGANIZATION]': '[СУБОРГАНИЗАЦИЯ]',
 '[CONDITIONS]': '[УСЛОВИЯ]',
 '[REPRESENTATIVE]': '[ПРЕДСТАВИТЕЛЬ]',
 '[NPS_AREA]': '[ЗОНА_АЭС]',
 '[DOCUMENT_NUMBER]': '[НОМЕР_ДОКУМЕНТА]',
 '[PROFESSION]': '[ПРОФЕССИЯ]',
 '[BRANCH]': '[ВЕТВЬ]',
 '[HOUSE]': '[ДОМ]',
 '[CONFERENCING_LINK]': '[ССЫЛКА_НА_КОНФЕРЕНЦИЮ]',
 '[CENTRE]': '[ЦЕНТР]',
 '[BRAND]': '[БРЕНД]',
 '[ОБЛАСТЬ]': '[ОБЛАСТЬ]',
 '[НОМЕР_ТЕЛЕФОНА]': '[НОМЕР_ТЕЛЕФОНА]',
 '[NAME]': '[ИМЯ]',
 '[NOMINATION_2]': '[НОМИНАЦИЯ_2]',
 '[REGULATORY_DOCUMENT]': '[НОРМАТИВНЫЙ_ДОКУМЕНТ]',
 '[GEN_DIR]': '[ОБЩИЙ_ДИРЕКТОР]',
 '[ORGANIZATION_NUMBER]': '[НОМЕР_ОРГАНИЗАЦИИ]',
 '[PERSON]': '[ЧЕЛОВЕК]',
 '[ADMINISTRATION]': '[АДМИНИСТРАЦИЯ]',
 '[OBJECT]': '[ОБЪЕКТ]',
 '[GROUP]': '[ГРУППА]',
 '[OKPO]': '[ОКПО]',
 '[THICKNESS]': '[ТОЛЩИНА]',
 '[ROUTE]': '[МАРШРУТ]',
 '[PAGE_COUNT]': '[СЧЕТ_СТРАНИЦ]',
 '[PRODUCT_CODE]': '[КОД_ПРОДУКТА]',
 '[PAGES]': '[СТРАНИЦЫ]',
 '[DOCUMENT]': '[ДОКУМЕНТ]',
 '[CONDITION]': '[СОСТОЯНИЕ]',
 '[VEHICLE_TYPE]': '[ТИП_АВТОМОБИЛЯ]',
 '[FIELD]': '[ПОЛЕ]',
 '[PHONE]': '[ТЕЛЕФОН]',
 '[ETHNIC_GROUP]': '[ЭТНИЧЕСКАЯ_ГРУППА]',
 '[MANAGER]': '[МЕНЕДЖЕР]',
 '[RECONSTRUCTION]': '[РЕКОНСТРУКЦИЯ]',
 '[FINANCIAL_DIRECTOR]': '[ФИНАНСОВЫЙ_ДИРЕКТОР]',
 '[НАЗВАНИЕ_КОМПАНИИ]': '[НАЗВАНИЕ_КОМПАНИИ]',
 '[COMPETITION_NAME]': '[НАЗВАНИЕ_КОНКУРСА]',
 '[SERVICES]': '[УСЛУГИ]',
 '[MEASURES]': '[МЕРЫ]',
 '[DESCRIPTION]': '[ОПИСАНИЕ]',
 '[RESOLUTION]': '[РАЗРЕШЕНИЕ]',
 '[DEPTH]': '[ГЛУБИНА]',
 '[HALL]': '[ЗАЛ]',
 '[FINANCИАL_DATA]': '[ФИНАНСОВЫЕ_ДАННЫЕ]',
 '[GOVERNMENT]': '[ПРАВИТЕЛЬСТВО]',
 '[CENTRAL_BANK_OF_RUSSIA]': '[ЦЕНТРАЛЬНЫЙ_БАНК_РОССИИ]',
 '[COPY_TO]': '[КОПИРОВАТЬ_В]',
 '[COMPRESSOR_MODEL]': '[МОДЕЛЬ_КОМПРЕССОРА]',
 '[ISLAND]': '[ОСТРОВ]',
 '[DIRECTION]': '[НАПРАВЛЕНИЕ]',
 '[PRODUCT_TYPE]': '[ТИП_ПРОДУКТА]',
 '[MONTH]': '[МЕСЯЦ]',
 '[GENERAL_DIRECTOR]': '[ГЕНЕРАЛЬНЫЙ_ДИРЕКТОР]',
 '[STATION]': '[СТАНЦИЯ]',
 '[POST_CODE]': '[ПОЧТОВЫЙ_ИНДЕКС]',
 '[WEB]': '[ВЕБ]',
 '[WORKPLACE]': '[РАБОЧОЕ_МЕСТО]',
 '[OFFICE_NUMBER]': '[НОМЕР_ОФИСА]',
 '[MAX_QUANTITY_ON_WAREHOUSE]': '[МАКС._КОЛИЧЕСТВО_НА_СКЛАДЕ]',
 '[FINANCИАЛЬ_ДАННЫЕ]': '[ФИНАНСОВЫЕ_ДАННЫЕ]',
 '[QUARTER]': '[ЧЕТВЕРТЬ]',
 '[FINANCИАЛЬ_DATA]': '[ФИНАНСОВЫЕ_ДАННЫЕ]',
 '[FINANCIAL_DATA]': '[ФИНАНСОВЫЕ_ДАННЫЕ]',
 '[DATE_RANGE]': '[ДИАПАЗОН_ДАТ]',
 '[YEAR+1]': '[ГОД+1]',
 '[DATE_TIME]': '[ДАТА_ВРЕМЯ]',
 '[DOCUMENT_TYPE]': '[ТИП_ДОКУМЕНТА]',
 '[FILE_EXTENSION]': '[РАСШИРЕНИЕ_ФАЙЛА]',
 '[ZIP_CODE]': '[ПОЧТОВЫЙ_ИНДЕКС]',
 '[CONTACT]': '[КОНТАКТ]',
 '[ВРЕМЯ]': '[ВРЕМЯ]',
 '[FILE_SIZE]': '[РАЗМЕР_ФАЙЛА]',
 '[MUNICIPAL_AREA]': '[МУНИЦИПАЛЬНЫЙ_РАЙОН]',
 '[INSTITUTION]': '[УЧРЕЖДЕНИЕ]',
 '[TAX_ID]': '[НАЛОГОВЫЙ_ИДЕНТИФИКАТОР]',
 '[TOTAL_PRICE]': '[ОБЩАЯ_ЦЕНА]'}

# %%
new_tags_dict = {}

for tag in tags_dict:
    new_tags_dict[tag] = tags_dict[tag][1:-1].lower() + '_тег'
    
new_tags_dict
# Out:
# {'[PROJECT]': 'проект_тег',
#  '[TYPE]': 'тип_тег',
#  '[SIZE]': 'размер_тег',
#  '[НОМЕР_ОБЪЕКТА]': 'номер_объекта_тег',
#  '[REGIONAL_OFFICE]': 'региональный_офис_тег',
#  '[NUMBER]': 'число_тег',
#  '[MUNICIPAL_DISTRICT]': 'муниципальный_округ_тег',
#  '[OGRN]': 'огрн_тег',
#  '[CITY]': 'город_тег',
#  '[TIME]': 'время_тег',
#  '[DIMENSIONS]': 'размеры_тег',
#  '[NUMBER_OF_PAGES]': 'количество_страниц_тег',
#  '[PRODUCT]': 'продукт_тег',
#  '[SIGNATURE]': 'подпись_тег',
#  '[SERVICE_AREA]': 'зона_обслуживания_тег',
#  '[LAW_NUMBER]': 'номер_закона_тег',
#  '[QUANTITY]': 'количество_тег',
#  '[PAGE]': 'страница_тег',
#  '[PRODUCT_MARK]': 'марка_продукта_тег',
#  '[PROJECT_NUMBER]': 'номер_проекта_тег',
#  '[EXECUTIVE_DIRECTOR]': 'исполнительный_директор_тег',
#  '[TEMPERATURE]': 'температура_тег',
#  '[DOMAIN]': 'домен_тег',
#  '[FILIAL]': 'филиал_тег',
#  '[DATE]': 'дата_тег',
#  '[KPP]': 'кпп_тег',
#  '[VOLUME]': 'объем_тег',
#  '[RESOURCE_TYPES]': 'типы_ресурсов_тег',
# ...

# %%
rr = {}
for i in raw_tags:
    rr[i] = 0
    
for i in range(len(df)):
    for j in df['text'][i].split():
        if j in raw_tags:
            rr[j] += 1
            
rr2 = sorted(rr, key=lambda x: rr[x])
# rr2
# for i in range(1, 26):
#     print(f'{rr2[-i]}')
    
rr3 = [(rr2[-i], rr[rr2[-i]], new_tags_dict[rr2[-i]]) for i in range(1, 26)]
dff = pd.DataFrame(rr3, columns=['стары тег', 'количество', 'новый тег'])
# print(dff.to_string())
# print(df)
dff
# Out:
#                       стары тег  количество                       новый тег
# 0                      [PERSON]       38374                     человек_тег
# 1              [FINANCIAL_DATA]       23245           финансовые_данные_тег
# 2                [ORGANIZATION]       19160                 организация_тег
# 3             [DOCUMENT_NUMBER]       18121             номер_документа_тег
# 4                   [DATE_TIME]       11266                  дата_время_тег
# 5                      [OBJECT]       10403                      объект_тег
# 6                      [NUMBER]        6872                       число_тег
# 7                     [PRODUCT]        4721                     продукт_тег
# 8                     [CONTACT]        4200                     контакт_тег
# 9                          [ID]        3128               идентификатор_тег
# 10                   [LOCATION]        1955                расположение_тег
# ...
