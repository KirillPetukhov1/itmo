# %%
pip install pandas seaborn openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_excel(r'C:\Users\k4484\itmo\itmo\proectnay_shkola\yandex_maps_review.xlsx')

# %%
df.tail(10)
# Out:
#                                                   address  \
# 499990                    Москва, улица Юных Ленинцев, 52
# 499991  Москва, Южный административный округ, район Би...
# 499992  Москва, Южный административный округ, район Би...
# 499993  Москва, Южный административный округ, район Би...
# 499994  Москва, Южный административный округ, район Би...
# 499995  Москва, Южный административный округ, район Би...
# 499996  Москва, Южный административный округ, район Би...
# 499997           Новосибирск, Коммунистическая улица, 48А
# 499998          Астраханская область, Харабалинский район
# 499999          Астраханская область, Харабалинский район
#
#                        name_ru  rating                  rubrics  \
# 499990  Petruccio. Pizza&Pasta     1.0   Ресторан;Кафе;Пиццерия
# 499991   Бирюлёво-Пассажирская     3.0  Железнодорожная станция
# 499992   Бирюлёво-Пассажирская     5.0  Железнодорожная станция
# 499993   Бирюлёво-Пассажирская     5.0  Железнодорожная станция
# ...

# %%
df_1 = df[['rating', 'text']]
df_1.rename(columns={'text':'comment'})
# Out:
#         rating                                            comment
# 0          3.0  Московский квартал 2.\nШумно : летом по ночам ...
# 1          5.0  Замечательная сеть магазинов в общем, хороший ...
# 2          1.0  Не знаю смутят ли кого-то данные правила, но я...
# 3          4.0  Хорошие условия аренды. \nДружелюбный персонал...
# 4          5.0  Топ мастер Ангелина топ во всех смыслах ) Немн...
# ...        ...                                                ...
# 499995     4.0  Охрана кривая но добрая, двери не закрываются ...
# 499996     4.0  По сравнению со многими современными платформа...
# 499997     5.0  Приятная атмосфера, прекрасное вино, волшебная...
# 499998     5.0  Был с семьёй 13.06.23 Отличное место. Рекоменд...
# 499999     5.0  Отличные декорации... Вблизи тяп-ляп,а на фото...
#
# [500000 rows x 2 columns]

# %%
df.describe()
# Out:
#              rating
# count  500000.00000
# mean        4.48160
# std         1.14625
# min         0.00000
# 25%         5.00000
# 50%         5.00000
# 75%         5.00000
# max         5.00000
